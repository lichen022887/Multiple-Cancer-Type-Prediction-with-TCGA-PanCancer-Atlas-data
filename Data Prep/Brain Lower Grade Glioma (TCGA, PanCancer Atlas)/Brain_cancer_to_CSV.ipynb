# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Brain_cancer.csv')

# %%
df.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id TCGA-CS-4938-01 TCGA-CS-4941-01 TCGA-CS-4942-01  \
# 0         NaN             NaN    Brain_cancer    Brain_cancer    Brain_cancer
# 1         NaN     100130426.0               0               0               0
# 2         NaN     100133144.0          8.7141         36.4493         11.8131
# 3         NaN     100134869.0         22.7523         21.1767         11.0242
# 4         NaN         10357.0         268.576         156.687         185.138
#
#   TCGA-CS-4943-01 TCGA-CS-4944-01 TCGA-CS-5390-01 TCGA-CS-5393-01  \
# 0    Brain_cancer    Brain_cancer    Brain_cancer    Brain_cancer
# 1               0               0               0               0
# 2          8.6116               0          5.3382          3.7845
# 3          5.0835          30.261         27.8886           8.723
# 4         269.836         216.341         159.759         198.188
#
#   TCGA-CS-5394-01  ... TCGA-VW-A8FI-01 TCGA-W9-A837-01 TCGA-WH-A86K-01  \
# ...

# %%
df.shape
# Out:
# (20532, 516)

# %%
Brain_cancer_train = df.iloc[:,1:102]

# %%
Brain_cancer_train.shape
# Out:
# (20532, 101)

# %%
Brain_cancer_train.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id TCGA-CS-4938-01 TCGA-CS-4941-01 TCGA-CS-4942-01  \
# 0         NaN             NaN    Brain_cancer    Brain_cancer    Brain_cancer
# 1         NaN     100130426.0               0               0               0
# 2         NaN     100133144.0          8.7141         36.4493         11.8131
# 3         NaN     100134869.0         22.7523         21.1767         11.0242
# 4         NaN         10357.0         268.576         156.687         185.138
#
#   TCGA-CS-4943-01 TCGA-CS-4944-01 TCGA-CS-5390-01 TCGA-CS-5393-01  \
# 0    Brain_cancer    Brain_cancer    Brain_cancer    Brain_cancer
# 1               0               0               0               0
# 2          8.6116               0          5.3382          3.7845
# 3          5.0835          30.261         27.8886           8.723
# 4         269.836         216.341         159.759         198.188
#
#   TCGA-CS-5394-01  ... TCGA-S9-A7R4-01 TCGA-S9-A7R7-01 TCGA-S9-A7R8-01  \
# ...

# %%
Brain_cancer_train.to_csv('Brain_cancer_train.csv', index = False)

# %%
Brain_cancer_test = pd.concat([df.iloc[:, 1:2], df.iloc[:, 103:123]], axis = 1)

# %%
Brain_cancer_test.head()
# Out:
#    Entrez_Gene_Id TCGA-DU-7009-01 TCGA-DU-7010-01 TCGA-DU-7011-01  \
# 0             NaN    Brain_cancer    Brain_cancer    Brain_cancer
# 1     100130426.0               0               0               0
# 2     100133144.0         19.2518          2.0555           8.969
# 3     100134869.0          22.515          2.7667           9.097
# 4         10357.0         234.441         172.625         191.632
#
#   TCGA-DU-7012-01 TCGA-DU-7013-01 TCGA-DU-7014-01 TCGA-DU-7015-01  \
# 0    Brain_cancer    Brain_cancer    Brain_cancer    Brain_cancer
# 1               0               0               0               0
# 2          7.5091         14.6093          5.6997           5.798
# 3          5.7755          10.103          1.6627          4.5662
# 4         200.721         263.285         213.328         231.774
#
#   TCGA-DU-7018-01 TCGA-DU-7019-01  ... TCGA-DU-7292-01 TCGA-DU-7294-01  \
# 0    Brain_cancer    Brain_cancer  ...    Brain_cancer    Brain_cancer
# ...

# %%
Brain_cancer_test.shape
# Out:
# (20532, 21)

# %%
Brain_cancer_test.to_csv('Brain_cancer_test.csv', index = False)

# %%
Brain_cancer_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20532 entries, 0 to 20531
# Columns: 464 entries, Hugo_Symbol to TCGA-TM-A7CF-01
# dtypes: float64(1), object(463)
# memory usage: 72.7+ MB
