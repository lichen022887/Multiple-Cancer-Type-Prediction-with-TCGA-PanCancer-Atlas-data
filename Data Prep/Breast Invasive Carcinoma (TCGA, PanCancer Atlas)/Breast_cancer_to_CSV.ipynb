# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Breast_cancer.csv')

# %%
df.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id TCGA-3C-AAAU-01 TCGA-3C-AALI-01 TCGA-3C-AALJ-01  \
# 0         NaN             NaN   Breast_cancer   Breast_cancer   Breast_cancer
# 1         NaN     100130426.0               0               0          0.9066
# 2         NaN     100133144.0         16.3644          9.2659         11.6228
# 3         NaN     100134869.0         12.9316          17.379          9.2294
# 4         NaN         10357.0         52.1503         69.7553         154.297
#
#   TCGA-3C-AALK-01 TCGA-4H-AAAK-01 TCGA-5L-AAT0-01 TCGA-5T-A9QA-01  \
# 0   Breast_cancer   Breast_cancer   Breast_cancer   Breast_cancer
# 1               0               0               0               0
# 2         12.0894          6.8468          3.9889          1.4644
# 3         11.0799         14.4298          13.609          8.9958
# 4         143.864         84.2128         114.257         107.563
#
#   TCGA-A1-A0SB-01  ... TCGA-UL-AAZ6-01 TCGA-UU-A93S-01 TCGA-V7-A7HQ-01  \
# ...

# %%
df.shape
# Out:
# (20532, 1084)

# %%
Breast_cancer_train = df.iloc[:, 1:102]

# %%
Breast_cancer_train.head()
# Out:
#    Entrez_Gene_Id TCGA-3C-AAAU-01 TCGA-3C-AALI-01 TCGA-3C-AALJ-01  \
# 0             NaN   Breast_cancer   Breast_cancer   Breast_cancer
# 1     100130426.0               0               0          0.9066
# 2     100133144.0         16.3644          9.2659         11.6228
# 3     100134869.0         12.9316          17.379          9.2294
# 4         10357.0         52.1503         69.7553         154.297
#
#   TCGA-3C-AALK-01 TCGA-4H-AAAK-01 TCGA-5L-AAT0-01 TCGA-5T-A9QA-01  \
# 0   Breast_cancer   Breast_cancer   Breast_cancer   Breast_cancer
# 1               0               0               0               0
# 2         12.0894          6.8468          3.9889          1.4644
# 3         11.0799         14.4298          13.609          8.9958
# 4         143.864         84.2128         114.257         107.563
#
#   TCGA-A1-A0SB-01 TCGA-A1-A0SD-01  ... TCGA-A2-A1FW-01 TCGA-A2-A1FX-01  \
# 0   Breast_cancer   Breast_cancer  ...   Breast_cancer   Breast_cancer
# ...

# %%
Breast_cancer_train.shape
# Out:
# (20532, 101)

# %%
Breast_cancer_train.to_csv('Breast_cancer_train.csv', index = False)

# %%
Breast_cancer_test = pd.concat([df.iloc[:, 1:2], df.iloc[:, 103:123]], axis = 1)

# %%
Breast_cancer_test.head()
# Out:
#    Entrez_Gene_Id TCGA-A2-A25D-01 TCGA-A2-A25E-01 TCGA-A2-A25F-01  \
# 0             NaN   Breast_cancer   Breast_cancer   Breast_cancer
# 1     100130426.0               0               0               0
# 2     100133144.0          0.9254         11.5629          2.6526
# 3     100134869.0          2.8827         11.0786          3.7857
# 4         10357.0         100.861         71.7013         96.5851
#
#   TCGA-A2-A3KC-01 TCGA-A2-A3KD-01 TCGA-A2-A3XS-01 TCGA-A2-A3XT-01  \
# 0   Breast_cancer   Breast_cancer   Breast_cancer   Breast_cancer
# 1               0               0               0               0
# 2          9.5154          7.6046         16.7663         20.1082
# 3         22.7942         10.4804         32.1504         18.6647
# 4         92.1711         80.2413         212.439           155.5
#
#   TCGA-A2-A3XU-01 TCGA-A2-A3XV-01  ... TCGA-A2-A3XX-01 TCGA-A2-A3XY-01  \
# 0   Breast_cancer   Breast_cancer  ...   Breast_cancer   Breast_cancer
# ...

# %%
Breast_cancer_test.shape
# Out:
# (20532, 21)

# %%
Breast_cancer_test.to_csv('Breast_cancer_test.csv', index = False)
