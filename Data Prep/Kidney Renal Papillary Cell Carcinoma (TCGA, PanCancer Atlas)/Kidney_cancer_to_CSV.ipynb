# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Kidney Cancer.csv')

# %%
df.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id TCGA-2K-A9WE-01 TCGA-2Z-A9J1-01 TCGA-2Z-A9J2-01  \
# 0         NaN             NaN   Kidney cancer   Kidney cancer   Kidney cancer
# 1         NaN     100130426.0               0               0               0
# 2         NaN     100133144.0          5.0494          8.0387          2.8619
# 3         NaN     100134869.0          5.7378         11.7854          3.3327
# 4         NaN         10357.0         54.6809         72.3727         28.9042
#
#   TCGA-2Z-A9J3-01 TCGA-2Z-A9J5-01 TCGA-2Z-A9J6-01 TCGA-2Z-A9J7-01  \
# 0   Kidney cancer   Kidney cancer   Kidney cancer   Kidney cancer
# 1               0               0               0               0
# 2          5.8053          1.3098         10.1249          9.2934
# 3          5.0525          7.3176         20.8596          9.1983
# 4         74.9367         74.7294         74.8326          56.484
#
#   TCGA-2Z-A9J8-01  ... TCGA-WN-AB4C-01 TCGA-Y8-A894-01 TCGA-Y8-A895-01  \
# ...

# %%
df.shape
# Out:
# (20532, 285)

# %%
Kidney_cancer_train = df.iloc[:, 1:102]

# %%
Kidney_cancer_train.shape
# Out:
# (20532, 101)

# %%
Kidney_cancer_train.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id TCGA-2K-A9WE-01 TCGA-2Z-A9J1-01 TCGA-2Z-A9J2-01  \
# 0         NaN             NaN   Kidney cancer   Kidney cancer   Kidney cancer
# 1         NaN     100130426.0               0               0               0
# 2         NaN     100133144.0          5.0494          8.0387          2.8619
# 3         NaN     100134869.0          5.7378         11.7854          3.3327
# 4         NaN         10357.0         54.6809         72.3727         28.9042
#
#   TCGA-2Z-A9J3-01 TCGA-2Z-A9J5-01 TCGA-2Z-A9J6-01 TCGA-2Z-A9J7-01  \
# 0   Kidney cancer   Kidney cancer   Kidney cancer   Kidney cancer
# 1               0               0               0               0
# 2          5.8053          1.3098         10.1249          9.2934
# 3          5.0525          7.3176         20.8596          9.1983
# 4         74.9367         74.7294         74.8326          56.484
#
#   TCGA-2Z-A9J8-01  ... TCGA-BQ-7055-01 TCGA-BQ-7058-01 TCGA-BQ-7059-01  \
# ...

# %%
Kidney_cancer_train.to_csv('Kidney_cancer_train.csv', index = False)

# %%
Kidney_cancer_test = pd.concat([df.iloc[:, 1:2], df.iloc[:, 103:123]], axis = 1)

# %%
Kidney_cancer_test
# Out:
#        Entrez_Gene_Id TCGA-B9-5155-01 TCGA-B9-5156-01 TCGA-B9-7268-01  \
# 0                 NaN   Kidney cancer   Kidney cancer   Kidney cancer
# 1         100130426.0               0               0               0
# 2         100133144.0               0          2.8145          3.0715
# 3         100134869.0          7.3155          4.8191         10.9189
# 4             10357.0         117.516         89.0707         42.7822
# ...               ...             ...             ...             ...
# 20527        440590.0          0.6361          7.3017          0.9539
# 20528         79699.0         1218.19         1144.71         845.151
# 20529          7791.0         7270.67          6238.3         6343.08
# 20530         23140.0         1180.66         1359.77         1463.28
# 20531         26009.0         759.542         729.505         645.469
#
#       TCGA-B9-A44B-01 TCGA-B9-A5W7-01 TCGA-B9-A5W8-01 TCGA-B9-A5W9-01  \
# ...

# %%
Kidney_cancer_test.to_csv('Kidney_cancer_test.csv', index = False)

# %%
Kidney_cancer_test.shape
# Out:
# (20532, 21)
