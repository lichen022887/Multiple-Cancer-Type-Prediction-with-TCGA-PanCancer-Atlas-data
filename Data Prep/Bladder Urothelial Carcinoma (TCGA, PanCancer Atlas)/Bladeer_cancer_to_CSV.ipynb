# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Bladder_cancer.csv')

# %%
df.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id TCGA-2F-A9KO-01 TCGA-2F-A9KP-01 TCGA-2F-A9KQ-01  \
# 0         NaN             NaN  Bladder_cancer  Bladder_cancer  Bladder_cancer
# 1         NaN     100130426.0               0               0               0
# 2         NaN     100133144.0         20.4373         16.1382         13.3333
# 3         NaN     100134869.0         37.8717         12.5759         10.7742
# 4         NaN         10357.0          123.09         137.886         104.678
#
#   TCGA-2F-A9KR-01 TCGA-2F-A9KT-01 TCGA-2F-A9KW-01 TCGA-4Z-AA7M-01  \
# 0  Bladder_cancer  Bladder_cancer  Bladder_cancer  Bladder_cancer
# 1               0               0               0               0
# 2         15.3523         14.0136          7.1159         22.4891
# 3          42.581         17.6427          2.3091          45.049
# 4         146.453         142.962         176.877         126.356
#
#   TCGA-4Z-AA7N-01  ... TCGA-ZF-AA4X-01 TCGA-ZF-AA51-01 TCGA-ZF-AA52-01  \
# ...

# %%
df.shape
# Out:
# (20532, 409)

# %%
Bladder_cancer_train = df.iloc[:, :101]

# %%
Bladder_cancer_train.shape
# Out:
# (20532, 101)

# %%
Bladder_cancer_train.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id TCGA-2F-A9KO-01 TCGA-2F-A9KP-01 TCGA-2F-A9KQ-01  \
# 0         NaN             NaN  Bladder_cancer  Bladder_cancer  Bladder_cancer
# 1         NaN     100130426.0               0               0               0
# 2         NaN     100133144.0         20.4373         16.1382         13.3333
# 3         NaN     100134869.0         37.8717         12.5759         10.7742
# 4         NaN         10357.0          123.09         137.886         104.678
#
#   TCGA-2F-A9KR-01 TCGA-2F-A9KT-01 TCGA-2F-A9KW-01 TCGA-4Z-AA7M-01  \
# 0  Bladder_cancer  Bladder_cancer  Bladder_cancer  Bladder_cancer
# 1               0               0               0               0
# 2         15.3523         14.0136          7.1159         22.4891
# 3          42.581         17.6427          2.3091          45.049
# 4         146.453         142.962         176.877         126.356
#
#   TCGA-4Z-AA7N-01  ... TCGA-DK-A1A7-01 TCGA-DK-A1AA-01 TCGA-DK-A1AB-01  \
# ...

# %%
Bladder_cancer_train.to_csv('Bladder_cancer_train.csv', index = False)

# %%
Bladder_cancer_test = pd.concat([df.iloc[:, 0:2], df.iloc[:, 103:123]], axis = 1)

# %%
Bladder_cancer_test.shape
# Out:
# (20532, 22)

# %%
Bladder_cancer_test.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id TCGA-DK-A2I6-01 TCGA-DK-A3IK-01 TCGA-DK-A3IL-01  \
# 0         NaN             NaN  Bladder_cancer  Bladder_cancer  Bladder_cancer
# 1         NaN     100130426.0               0               0               0
# 2         NaN     100133144.0          1.8399         28.1985         10.0595
# 3         NaN     100134869.0          4.3225         21.5282          9.2762
# 4         NaN         10357.0         229.713         116.146         112.112
#
#   TCGA-DK-A3IM-01 TCGA-DK-A3IN-01 TCGA-DK-A3IQ-01 TCGA-DK-A3IS-01  \
# 0  Bladder_cancer  Bladder_cancer  Bladder_cancer  Bladder_cancer
# 1               0               0               0               0
# 2         12.9442          5.1215          9.8872         12.8917
# 3          2.4615           2.729         11.6513          8.5096
# 4         111.284         83.3047         88.5538         179.108
#
#   TCGA-DK-A3IT-01  ... TCGA-DK-A3WW-01 TCGA-DK-A3WX-01 TCGA-DK-A3WY-01  \
# ...

# %%
Bladder_cancer_test.to_csv('Bladder_cancer_test.csv', index = False)

# %%
Gene_name_id = df.iloc[:, :2]
Gene_name_id
# Out:
#       Hugo_Symbol  Entrez_Gene_Id
# 0             NaN             NaN
# 1             NaN     100130426.0
# 2             NaN     100133144.0
# 3             NaN     100134869.0
# 4             NaN         10357.0
# ...           ...             ...
# 20527      ZYG11A        440590.0
# 20528      ZYG11B         79699.0
# 20529         ZYX          7791.0
# 20530       ZZEF1         23140.0
# 20531        ZZZ3         26009.0
#
# [20532 rows x 2 columns]

# %%
Gene_name_id.to_csv('Gene_name_id.csv', index = False)
