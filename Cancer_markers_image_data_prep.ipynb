# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df_raw = pd.read_csv('Cancer_train.csv', index_col='Entrez_Gene_Id')

# %%
Cancer_markers = df_raw.transpose()

# %%
Cancer_markers.head()
# Out:
# Entrez_Gene_Id      NaN         100130426.0 100133144.0 100134869.0  \
# Hugo_Symbol                 NaN         NaN         NaN         NaN
# TCGA-2F-A9KO-01  Bladder_cancer           0     20.4373     37.8717
# TCGA-2F-A9KP-01  Bladder_cancer           0     16.1382     12.5759
# TCGA-2F-A9KQ-01  Bladder_cancer           0     13.3333     10.7742
# TCGA-2F-A9KR-01  Bladder_cancer           0     15.3523      42.581
#
# Entrez_Gene_Id  10357.0     10431.0     136542.0    155060.0    26823.0      \
# Hugo_Symbol             NaN         NaN         NaN         NaN         NaN
# TCGA-2F-A9KO-01      123.09     702.041           0     406.997      0.5831
# TCGA-2F-A9KP-01     137.886     882.231           0     182.272      0.8323
# TCGA-2F-A9KQ-01     104.678     954.103           0     224.849           0
# TCGA-2F-A9KR-01     146.453      487.21           0     472.964      2.3743
#
# Entrez_Gene_Id  280660.0     ... 55055.0     11130.0     7789.0       \
# ...

# %%
Cancer_markers.columns = Cancer_markers.iloc[0]

# %%
Cancer_markers.drop('Hugo_Symbol', inplace = True)

# %%
Cancer_markers.head()
# Out:
# Hugo_Symbol                 NaN NaN      NaN      NaN      NaN      NaN NaN  \
# TCGA-2F-A9KO-01  Bladder_cancer   0  20.4373  37.8717   123.09  702.041   0
# TCGA-2F-A9KP-01  Bladder_cancer   0  16.1382  12.5759  137.886  882.231   0
# TCGA-2F-A9KQ-01  Bladder_cancer   0  13.3333  10.7742  104.678  954.103   0
# TCGA-2F-A9KR-01  Bladder_cancer   0  15.3523   42.581  146.453   487.21   0
# TCGA-2F-A9KT-01  Bladder_cancer   0  14.0136  17.6427  142.962  954.777   0
#
# Hugo_Symbol          NaN     NaN NaN  ...   ZWILCH    ZWINT     ZXDA     ZXDB  \
# TCGA-2F-A9KO-01  406.997  0.5831   0  ...  694.857  554.519  102.624  776.676
# TCGA-2F-A9KP-01  182.272  0.8323   0  ...  718.119  969.621   37.037  316.688
# TCGA-2F-A9KQ-01  224.849       0   0  ...  532.536  795.086  60.2689  378.303
# TCGA-2F-A9KR-01  472.964  2.3743   0  ...  616.848  568.412  45.5869  470.115
# TCGA-2F-A9KT-01  234.596       0   0  ...  726.625  1087.05   17.524  281.515
#
# ...

# %%
Cancer_markers.columns.values[0] = 'Disease'

# %%
Cancer_markers.head()
# Out:
# Hugo_Symbol             Disease NaN      NaN      NaN      NaN      NaN NaN  \
# TCGA-2F-A9KO-01  Bladder_cancer   0  20.4373  37.8717   123.09  702.041   0
# TCGA-2F-A9KP-01  Bladder_cancer   0  16.1382  12.5759  137.886  882.231   0
# TCGA-2F-A9KQ-01  Bladder_cancer   0  13.3333  10.7742  104.678  954.103   0
# TCGA-2F-A9KR-01  Bladder_cancer   0  15.3523   42.581  146.453   487.21   0
# TCGA-2F-A9KT-01  Bladder_cancer   0  14.0136  17.6427  142.962  954.777   0
#
# Hugo_Symbol          NaN     NaN NaN  ...   ZWILCH    ZWINT     ZXDA     ZXDB  \
# TCGA-2F-A9KO-01  406.997  0.5831   0  ...  694.857  554.519  102.624  776.676
# TCGA-2F-A9KP-01  182.272  0.8323   0  ...  718.119  969.621   37.037  316.688
# TCGA-2F-A9KQ-01  224.849       0   0  ...  532.536  795.086  60.2689  378.303
# TCGA-2F-A9KR-01  472.964  2.3743   0  ...  616.848  568.412  45.5869  470.115
# TCGA-2F-A9KT-01  234.596       0   0  ...  726.625  1087.05   17.524  281.515
#
# ...

# %%
Cancer_markers.to_csv('Cancer_markers.csv', index = False)
